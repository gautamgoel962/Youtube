# %%
print("hello")
# Out:
# hello

# %%
from micrograd.engine import Value

# %%
a = Value(-4.0)
b = Value(2.0)
c = Value(3.0)
d = a * b + c

# %%
print(d)
# Out:
# Value(data=-5.0, grad=0)

# %%
print(c)
# Out:
# Value(data=-2.0, grad=0)
