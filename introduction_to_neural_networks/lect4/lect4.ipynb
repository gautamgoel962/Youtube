# %%
print("hello")
# Out:
# hello

# %%
a = 2.0
b = -3.0
c = 10
d = a * b + c

# %%
print(d)
# Out:
# 4.0

# %%
# h = 0.0001
# a += h
# d_a = a * b + c 
# print(d_a)

# %%
# slope = (d_a - d) / h
# print(slope)
# Out:
# -3.000000000010772

# %%
# h = 0.0001
# b += h 
# d_b = a * b + c 
# print(d)
# print(d_b)
# slope = (d_b - d) / h
# print(slope)
# Out:
# 4.0
# 4.0002
# 2.0000000000042206

# %%
h = 0.000000001 
c += h 
d_c = a * b + c 
print(d)
print(d_c)
slope = (d_c - d) / h 
print(slope)
# Out:
# 4.0
# 4.000000001
# 1.000000082740371
